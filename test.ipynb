# %%
pmlabel = 2079
pmunlabel = 327
lslabel = 228
lsunlabel = 5622

for i in [0.01, 0.1, 0.5, 1.0]:
    ls_num_labeled = lslabel
    ls_num_unlabeled = lsunlabel * i
    pm_num_labeled = pmlabel * i
    pm_num_unlabeled = pmunlabel
    print("ls_num_labeled: %d, ls_num_unlabeled: %d, pm_num_labeled: %d, pm_num_unlabeled: %d" % (ls_num_labeled, ls_num_unlabeled, pm_num_labeled, pm_num_unlabeled))
# Out:
# ls_num_labeled: 228, ls_num_unlabeled: 56, pm_num_labeled: 20, pm_num_unlabeled: 327
# ls_num_labeled: 228, ls_num_unlabeled: 562, pm_num_labeled: 207, pm_num_unlabeled: 327
# ls_num_labeled: 228, ls_num_unlabeled: 2811, pm_num_labeled: 1039, pm_num_unlabeled: 327
# ls_num_labeled: 228, ls_num_unlabeled: 5622, pm_num_labeled: 2079, pm_num_unlabeled: 327

# %%
5850 - 228
# Out:
# 5622
